# %% [markdown]
# # Pandas (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %%
import pandas as pd

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
pwd
# Out:
# 'C:\\Users\\Артём\\OneDrive - ФГОБУ ВО Финансовый университет при Правительстве РФ\\Учёба\\3 курс\\Технологии обработки BD\\ТОБД22-ПМ20-Материалы к семинарам\\02_pandas'

# %%
df = pd.read_csv('C:\\Users\\Артём\\OneDrive - ФГОБУ ВО Финансовый университет при Правительстве РФ\\Учёба\\3 курс\\Технологии обработки BD\\ТОБД22-ПМ20-Материалы к семинарам\\02_pandas\\02_pandas_data\\sp500hst.txt', sep=',', header=None, names=["date", "ticker", "open", "high", "low", "close", "volume"])
df
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176
# ...          ...    ...    ...      ...     ...    ...     ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
df.iloc[:, 3:7].mean()
# Out:
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df.head(2)
# Out:
#         date ticker   open   high    low  close  volume
# 0 2009-08-21      A  25.60  25.61  25.22  25.55   34758
# 1 2009-08-24      A  25.64  25.74  25.33  25.50   22247

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# ticker            object
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %%
df['month'] = df['date'].dt.month
df.head(5)
# Out:
#         date ticker   open     high     low  close  volume  month
# 0 2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1 2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2 2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3 2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4 2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8

# %% [markdown]
# ## Лабораторная работа №2.1

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('C:\\Users\\Артём\\OneDrive - ФГОБУ ВО Финансовый университет при Правительстве РФ\\Учёба\\3 курс\\Технологии обработки BD\\ТОБД22-ПМ20-Материалы к семинарам\\02_pandas\\02_pandas_data\\recipes_sample.csv', sep=',',
                      parse_dates=['submitted'])
reviews = pd.read_csv('C:\\Users\\Артём\\OneDrive - ФГОБУ ВО Финансовый университет при Правительстве РФ\\Учёба\\3 курс\\Технологии обработки BD\\ТОБД22-ПМ20-Материалы к семинарам\\02_pandas\\02_pandas_data\\reviews_sample.csv', sep=',')

# %%
recipes.head(10)
# Out:
#                                        name      id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup   44123       90           35193
# 1        healthy for them  yogurt popsicles   67664       10           91970
# 2              i can t believe it s spinach   38798       30            1533
# 3                      italian  gut busters   35173       45           22724
# 4  love is in the air  beef fondue   sauces   84797       25            4470
# 5                  mennonite  corn fritters   44045       15           41706
# 6                      open sesame  noodles  107229       28          173674
# 7                say what   banana sandwich   95926        5          118163
# 8        1 in canada chocolate chip cookies  453467       45         1848091
# 9                    412 broccoli casserole  306168       40           50969
#
#    submitted  n_steps                                        description  \
# ...

# %%
reviews.head(10)
# Out:
#    Unnamed: 0     user_id  recipe_id        date  rating  \
# 0      370476       21752      57993  2003-05-01       5
# 1      624300      431813     142201  2007-09-16       5
# 2      187037      400708     252013  2008-01-10       4
# 3      706134  2001852463     404716  2017-12-11       5
# 4      312179       95810     129396  2008-03-14       5
# 5      910362       35106      31322  2003-01-03       4
# 6      212649      404333     199579  2006-12-10       5
# 7      815389      162888      16067  2005-12-09       5
# 8      642377       89831      33715  2007-07-03       5
# 9     1023302      308434      11252  2008-12-14       5
#
#                                               review
# 0  Last week whole sides of frozen salmon fillet ...
# 1  So simple and so tasty!  I used a yellow capsi...
# 2  Very nice breakfast HH, easy to make and yummy...
# 3  These are a favorite for the holidays and so e...
# 4  Excellent soup!  The tomato flavor is just gre...
# ...

# %%
reviews.columns = ['id', *reviews.columns[1:]]
len(reviews.id.unique()) / len(reviews) # После этого можно сделать вывод, что все значении уникальные
# Out:
# 1.0

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126696 entries, 0 to 126695
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         126696 non-null  int64
#  1   user_id    126696 non-null  int64
#  2   recipe_id  126696 non-null  int64
#  3   date       126696 non-null  object
#  4   rating     126696 non-null  int64
#  5   review     126679 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 5.8+ MB

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print("-"*30)
print("Missing values of each column")
print("-"*30)
print(recipes.isna().sum())
print("-"*30)
print("Total rows with missing values / Total number of rows =",(recipes.shape[0] - recipes.dropna().shape[0])/len(recipes))
# Out:
# ------------------------------
# Missing values of each column
# ------------------------------
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
# ------------------------------
# Total rows with missing values / Total number of rows = 0.5684666666666667

# %%
print("-"*30)
print("Missing values of each column")
print("-"*30)
print(reviews.isna().sum())
print("-"*30)
print("Total rows with missing values / Total number of rows =",(reviews.shape[0] - reviews.dropna().shape[0])/len(reviews))
# Out:
# ------------------------------
# Missing values of each column
# ------------------------------
# id            0
# user_id       0
# recipe_id     0
# date          0
# rating        0
# review       17
# dtype: int64
# ------------------------------
# Total rows with missing values / Total number of rows = 0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте и выведите на экран среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
recipes_mean = recipes.mean()
print('\nMean\n------') 
print(recipes_mean)
# Out:
# Mean
# ------
# id                2.218793e+05
# minutes           1.233581e+02
# contributor_id    5.635901e+06
# n_steps           9.805582e+00
# n_ingredients     9.008286e+00
# dtype: float64

# %%
reviews_mean = reviews.rating.mean()
print('\nMean_rating\n------') 
print(reviews_mean)
# Out:
# Mean_rating
# ------
# 4.410802235271832

# %% [markdown]
# 1.5 Создайте и выведите на экран серию из 10 случайных названий рецептов.

# %%
sr1 = pd.Series(recipes['name'].sample(10))
sr1
# Out:
# 26381                              sunrise delight oatmeal
# 19987                        pasta with fresh tomato sauce
# 4520     canadian bacon split pea   lentil soup  crock pot
# 22166                         raspberry cheesecake muffins
# 18041                             momma s fair funnel cake
# 3268                            bleu cheese cold cole slaw
# 13439                       healthy blueberry banana bread
# 26782                             sweet stuffed cannelloni
# 1390     aunt trish s salad dressing  from the pioneer ...
# 21264                           pork sausages with lentils
# Name: name, dtype: object

# %% [markdown]
# 1.6 Выведите на экран строку с __номером__ `54200`. Выведите на экран строку с __индексом__ `54200`.

# %%
# Cтрока с номером 54200 из reviews
reviews.loc[54200]
# Out:
# id                                                      667742
# user_id                                                 813584
# recipe_id                                                  916
# date                                                2008-08-16
# rating                                                       5
# review       I've made this 3-4 times already and forgot to...
# Name: 54200, dtype: object

# %%
# Строка с индексом 54200 из reviews 
reviews.iloc[54200]
# Out:
# id                                                      667742
# user_id                                                 813584
# recipe_id                                                  916
# date                                                2008-08-16
# rating                                                       5
# review       I've made this 3-4 times already and forgot to...
# Name: 54200, dtype: object

# %% [markdown]
# 1.7 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
new_ind = pd.Series([i for i in range(len(reviews))])
reviews.set_index([new_ind])
# Out:
#              id     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.8 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes.loc[(recipes.minutes < 21) & (recipes.n_ingredients < 6)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id  submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
# Решение задачи в 1.1
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes.loc[recipes.submitted < '2011-01-01']
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes.description.str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes.name = recipes.name.map(lambda x: x.lower())
recipes.name
# Out:
# 0               george s at the cove  black bean soup
# 1                  healthy for them  yogurt popsicles
# 2                        i can t believe it s spinach
# 3                                italian  gut busters
# 4            love is in the air  beef fondue   sauces
#                              ...
# 29995    zurie s holey rustic olive and cheddar bread
# 29996            zwetschgenkuchen  bavarian plum cake
# 29997     zwiebelkuchen   southwest german onion cake
# 29998                                     zydeco soup
# 29999          cookies by design   cookies on a stick
# Name: name, Length: 30000, dtype: object

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
# Функция для подсчёта слов
def count_words(s):
    s = s.split(' ')
    for i in range(s.count('')):
        s.remove('')
    return len(s)

recipes['name_word_count'] = recipes.name.map(lambda x: count_words(x))

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...
